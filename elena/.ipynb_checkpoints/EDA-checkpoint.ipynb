# %%
import numpy as np
import pandas as pd
import tensorflow as tf
import matplotlib.pyplot as plt
import seaborn as sns
import datetime
import scipy.stats as stats
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from collections import Counter

# %% [markdown]
# ## Exploratory Data Analysis

# %%
train_df = pd.read_csv('dataset/fraud_and_nonfraud.csv') #set index on 'id' column

# %%
train_df.head()
# Out:
#    paymentMethod_cvv paymentMethod_cardNumber amount_currency  amount_value  \
# 0                 53      2397-5582-2235-0543             USD     116943.85
# 1                 69      8723-7227-4509-4378             USD     247841.51
# 2                 73      4898-6794-3332-3641            EURO      91399.41
# 3                682      3736-6688-6660-0131             USD     205504.45
# 4                490      5420-1578-5601-8001            EURO     180084.36
#
#    channel deviceDetails_browser deviceDetails_device deviceDetails_deviceIp  \
# 0   mobile                  edge                  pos         142.126.240.34
# 1   mobile                  edge                   pc          107.157.153.9
# 2   online                chrome               mobile         21.149.214.233
# 3   mobile                chrome                  pos          12.46.252.208
# 4  virtual                chrome                   pc           28.76.148.31
#
#    merchantRefTransactionId paymentMethod_apmType paymentMethod_cardSubType  \
# 0                1499861185            magstripe                   Prepaid
# 1                9150392312                  nfcc                   Student
# 2                8157169694            magstripe                    Student
# 3                5304053509                  chip                   Student
# 4                7829509908            magstripe                    Student
#
#   paymentMethod_cardType  paymentMethod_expiryMonth  paymentMethod_expiryYear  \
# 0               Discover                          2                      2020
# 1       American Express                          3                      2020
# 2             MasterCard                         12                      2020
# 3       American Express                          1                      2019
# 4                   Visa                          6                      2020
#
#    paymentMethod_expiryDay transaction_time  class  \
# 0                        9         21:21:15      0
# 1                       23         11:36:17      0
# 2                       11           2:54:8      1
# 3                        7          3:23:17      0
# 4                       23          9:14:11      0
#
#   paymentMethod_encodedPaymentToken
# 0                          DEoNxEHP
# 1                          bdWKPCoD
# 2                          oYNftqLK
# 3                          NPBHFIZQ
# 4                          sJNNJmrS

# %%
train_df.shape
# Out:
# (1200000, 18)

# %%
train_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1200000 entries, 0 to 1199999
# Data columns (total 18 columns):
# paymentMethod_cvv                    1200000 non-null int64
# paymentMethod_cardNumber             1200000 non-null object
# amount_currency                      1200000 non-null object
# amount_value                         1200000 non-null float64
# channel                              1200000 non-null object
# deviceDetails_browser                1200000 non-null object
# deviceDetails_device                 1200000 non-null object
# deviceDetails_deviceIp               1200000 non-null object
# merchantRefTransactionId             1200000 non-null int64
# paymentMethod_apmType                1200000 non-null object
# paymentMethod_cardSubType            1200000 non-null object
# paymentMethod_cardType               1200000 non-null object
# paymentMethod_expiryMonth            1200000 non-null int64
# paymentMethod_expiryYear             1200000 non-null int64
# paymentMethod_expiryDay              1200000 non-null int64
# transaction_time                     1200000 non-null object
# class                                1200000 non-null int64
# paymentMethod_encodedPaymentToken    1200000 non-null object
# dtypes: float64(1), int64(6), object(11)
# memory usage: 164.8+ MB

# %% [markdown]
# We can clearly see that <b>we don't have any null values</b> in the data which is bound to happen in such datasets as each and every information is very necessary else the transaction isn't processed.

# %% [markdown]
# ### Columns story
# - <b>integer type columns</b>:
#     - merchantRefTransactionId,
#     - paymentMethod_cvv,
#     - paymentMethod_cvv,
#     - paymentMethod_expiryMonth,
#     - paymentMethod_expiryYear.
# - <b>float type columns</b>: amount_value.
# - <b>object (str) type columns</b>:
#     - amount_currency,
#     - channel,
#     - deviceDetails_browser,
#     - deviceDetails_device,
#     - deviceDetails_deviceIp,
#     - paymentMethod_apmType,
#     - paymentMethod_cardNumber,
#     - paymentMethod_cardType,
#     - paymentMethod_cardSubType,
#     - paymentMethod_encodedPaymentToken.
# - <b>object (date) type columns</b>: transaction_time.
# - <b>class</b>: 1 - fraun, 0 - non-fraud

# %%
train_df.columns
# Out:
# Index(['paymentMethod_cvv', 'paymentMethod_cardNumber', 'amount_currency',
#        'amount_value', 'channel', 'deviceDetails_browser',
#        'deviceDetails_device', 'deviceDetails_deviceIp',
#        'merchantRefTransactionId', 'paymentMethod_apmType',
#        'paymentMethod_cardSubType', 'paymentMethod_cardType',
#        'paymentMethod_expiryMonth', 'paymentMethod_expiryYear',
#        'paymentMethod_expiryDay', 'transaction_time', 'class',
#        'paymentMethod_encodedPaymentToken'],
#       dtype='object')

# %%
train_df.dtypes
# Out:
# paymentMethod_cvv                      int64
# paymentMethod_cardNumber              object
# amount_currency                       object
# amount_value                         float64
# channel                               object
# deviceDetails_browser                 object
# deviceDetails_device                  object
# deviceDetails_deviceIp                object
# merchantRefTransactionId               int64
# paymentMethod_apmType                 object
# paymentMethod_cardSubType             object
# paymentMethod_cardType                object
# paymentMethod_expiryMonth              int64
# paymentMethod_expiryYear               int64
# paymentMethod_expiryDay                int64
# transaction_time                      object
# class                                  int64
# paymentMethod_encodedPaymentToken     object
# dtype: object

# %% [markdown]
# ### Features histogram

# %%
def plot_numerical_feats_distribution(columns):
    fig=plt.figure(figsize=(20, 20))
    for i, feature in enumerate(columns):
        ax=fig.add_subplot(2, 2, i+1)
        train_df[feature].hist(bins=20,
                                ax=ax,
                                facecolor='midnightblue')
        ax.set_title(feature+" Distribution", color='DarkRed')
        ax.set_yscale('log')
    fig.tight_layout()  
    plt.show()

# %%
numerical_columns = ['paymentMethod_cvv', 
                     'paymentMethod_expiryMonth', 
                     'paymentMethod_expiryYear',
                     'amount_value']

# %%
plot_numerical_feats_distribution(numerical_columns)

# %%
def plot_str_feats_distribution():
    fig, axes = plt.subplots(nrows=3, ncols=2, figsize=(20,20))
    train_df['amount_currency'].value_counts().plot('bar', ax=axes[0, 0])
    train_df['deviceDetails_browser'].value_counts().plot('bar', ax=axes[0, 1])
    train_df['deviceDetails_device'].value_counts().plot('bar', ax=axes[1, 0])
    train_df['paymentMethod_apmType'].value_counts().plot('bar', ax=axes[1, 1])
    train_df['paymentMethod_cardType'].value_counts().plot('bar', ax=axes[2, 0])    
    train_df['paymentMethod_cardSubType'].value_counts().plot('bar', ax=axes[2, 1])

# %%
plot_str_feats_distribution()

# %% [markdown]
# ### Fraudulent vs. Non-Fraudulent Transactions
# - balanced data set

# %%
new_counts = train_df['class'].value_counts()
plt.figure(figsize=(8,6))
sns.barplot(x=new_counts.index, y=new_counts)
plt.title('Count of Fraudulent vs. Non-Fraudulent Transactions')
plt.ylabel('Count')
plt.xlabel('Class (0:Non-Fraudulent, 1:Fraudulent)')
# Out:
# Text(0.5, 0, 'Class (0:Non-Fraudulent, 1:Fraudulent)')

# %% [markdown]
# ### transaction_time in the foreground

# %%
initial_time = pd.DataFrame()
initial_time['time'] = train_df['paymentMethod_expiryYear'].astype(str) + "-" + train_df['paymentMethod_expiryMonth'].astype(str) + "-"  + train_df['paymentMethod_expiryDay'].astype(str) + " " + train_df['transaction_time'].astype(str)

# %%
train_df['time_concat'] = initial_time['time']

# %%
train_df.head()
# Out:
#    paymentMethod_cvv paymentMethod_cardNumber amount_currency  amount_value  \
# 0                 53      2397-5582-2235-0543             USD     116943.85
# 1                 69      8723-7227-4509-4378             USD     247841.51
# 2                 73      4898-6794-3332-3641            EURO      91399.41
# 3                682      3736-6688-6660-0131             USD     205504.45
# 4                490      5420-1578-5601-8001            EURO     180084.36
#
#    channel deviceDetails_browser deviceDetails_device deviceDetails_deviceIp  \
# 0   mobile                  edge                  pos         142.126.240.34
# 1   mobile                  edge                   pc          107.157.153.9
# 2   online                chrome               mobile         21.149.214.233
# 3   mobile                chrome                  pos          12.46.252.208
# 4  virtual                chrome                   pc           28.76.148.31
#
#    merchantRefTransactionId paymentMethod_apmType paymentMethod_cardSubType  \
# 0                1499861185            magstripe                   Prepaid
# 1                9150392312                  nfcc                   Student
# 2                8157169694            magstripe                    Student
# 3                5304053509                  chip                   Student
# 4                7829509908            magstripe                    Student
#
#   paymentMethod_cardType  paymentMethod_expiryMonth  paymentMethod_expiryYear  \
# 0               Discover                          2                      2020
# 1       American Express                          3                      2020
# 2             MasterCard                         12                      2020
# 3       American Express                          1                      2019
# 4                   Visa                          6                      2020
#
#    paymentMethod_expiryDay transaction_time  class  \
# 0                        9         21:21:15      0
# 1                       23         11:36:17      0
# 2                       11           2:54:8      1
# 3                        7          3:23:17      0
# 4                       23          9:14:11      0
#
#   paymentMethod_encodedPaymentToken         time_concat
# 0                          DEoNxEHP   2020-2-9 21:21:15
# 1                          bdWKPCoD  2020-3-23 11:36:17
# 2                          oYNftqLK   2020-12-11 2:54:8
# 3                          NPBHFIZQ    2019-1-7 3:23:17
# 4                          sJNNJmrS   2020-6-23 9:14:11

# %%
time_in_seconds = []
for time_val in initial_time['time']:
    date_time_obj = datetime.datetime.strptime(time_val, '%Y-%m-%d %H:%M:%S')
    time_in_seconds.append(date_time_obj.timestamp())

# %%
train_df = train_df.assign(time_in_seconds = time_in_seconds)

# %%
dif_time = []
the_older_trans_date = min(time_in_seconds)
for time_val in time_in_seconds:
    delta = time_val - the_older_trans_date
    dif_time.append(delta)

# %%
train_df = train_df.assign(time_dif = dif_time)

# %%
train_df.sort_values(by=['time_dif'], inplace=True)

# %%
train_df.head()
# Out:
#          paymentMethod_cvv paymentMethod_cardNumber amount_currency  \
# 590377                 441      4611-4927-2322-6577            EURO
# 658305                  41      2032-3412-1714-6899             USD
# 1051088                157      4538-8383-1466-2300            EURO
# 1016686                793      8104-2439-8607-2131            EURO
# 550838                 377      1545-1639-3559-5292             USD
#
#          amount_value channel deviceDetails_browser deviceDetails_device  \
# 590377      212992.94  mobile                  edge                  pos
# 658305      676023.17  mobile                chrome                  pos
# 1051088     282907.31  online               mozilla                   pc
# 1016686     680491.34     pos                chrome                   pc
# 550838      151890.10  mobile                  edge                  pos
#
#         deviceDetails_deviceIp  merchantRefTransactionId  \
# 590377         151.137.102.239                3511396555
# 658305           186.199.170.5                5147368594
# 1051088          196.255.149.2                3511663699
# 1016686          63.69.103.166                7435542379
# 550838          247.169.175.31                5474502049
#
#         paymentMethod_apmType    ...    paymentMethod_cardType  \
# 590377                   nfcc    ...                       JCB
# 658305             magstripe     ...          American Express
# 1051088                  nfcc    ...                  Discover
# 1016686            magstripe     ...                       JCB
# 550838                   nfcc    ...                MasterCard
#
#         paymentMethod_expiryMonth  paymentMethod_expiryYear  \
# 590377                          1                      2019
# 658305                          1                      2019
# 1051088                         1                      2019
# 1016686                         1                      2019
# 550838                          1                      2019
#
#          paymentMethod_expiryDay  transaction_time class  \
# 590377                         1            0:1:55     0
# 658305                         1            0:2:16     0
# 1051088                        1            0:2:54     0
# 1016686                        1             0:3:9     0
# 550838                         1            0:3:58     0
#
#          paymentMethod_encodedPaymentToken      time_concat time_in_seconds  \
# 590377                            UrvpXKic  2019-1-1 0:1:55    1.546294e+09
# 658305                            PSfWqdNP  2019-1-1 0:2:16    1.546294e+09
# 1051088                           QjSwwLmB  2019-1-1 0:2:54    1.546294e+09
# 1016686                           grauebFp   2019-1-1 0:3:9    1.546294e+09
# 550838                            NURyFUyu  2019-1-1 0:3:58    1.546294e+09
#
#          time_dif
# 590377        0.0
# 658305       21.0
# 1051088      59.0
# 1016686      74.0
# 550838      123.0
#
# [5 rows x 21 columns]

# %% [markdown]
# ### Normalized or not time_dif?
# <b>Time variable is also not normalized.</b> So it must be normalized.

# %%
sns.distplot(train_df['time_dif'], fit=stats.norm)

# %%
train_df['norm_time_dif'] = StandardScaler().fit_transform(train_df[['time_dif']])

# %%
sns.distplot(train_df['norm_time_dif'], fit=stats.norm)

# %% [markdown]
# ### Normalized or not amount_value?
# Clearly the amount_value variable is not normalized, so we'll normalize it frist.

# %%
sns.distplot(train_df['amount_value'],fit=stats.norm)

# %%
train_df['norm_amount'] = StandardScaler().fit_transform(train_df[['amount_value']])

# %%
sns.distplot(train_df['norm_amount'],fit=stats.norm)

# %% [markdown]
# ### When do people shop?
# Try to visualize when people shop and whan credit fraud happens and if there is a pattern.
#
# !! NO PATTERNS FOUND.

# %%
time_anaysis = train_df[['time_concat', 'amount_value', 'class']].copy()

# %%
def convert_to_dt(s):
    return datetime.datetime.strptime(s, '%Y-%m-%d %H:%M:%S')

# %%
time_anaysis['time_concat'] = time_anaysis.time_concat.apply(convert_to_dt)

# %%
time_anaysis['hour_of_the_day'] = time_anaysis.time_concat.dt.hour

# %%
time_analysis_grouped = time_anaysis.groupby(['class', 'hour_of_the_day'])['amount_value'].count()

# %%
plt.figure(figsize = (10, 6))
valid_transactions = time_analysis_grouped[0].copy()
valid_transactions.name = 'Number of transactions'
valid_transactions.plot.bar(title = '# of legitimate credit card transactions per hour', legend = True)

# %%
plt.figure(figsize = (10, 6))
fraud_transactions = time_analysis_grouped[1].copy()
fraud_transactions.name = 'Number of transactions'
fraud_transactions.plot.bar(title = '# of fraud credit card transactions per hour', legend = True)

# %% [markdown]
# ### Are fraudulent transactions of higher value than non-fraudulent transactions?
# It would be interesting to see if fraudulent transactions are in general higher value than non-fraudulent transactions or not.
#
# The <b>Null</b> hypothesis (H0): <i>Fraudulent transactions are of similar or lower value as normal transactions.</i>
#
# The <b>Alternative</b> hypothesis (HA): <i>Fraudulent transactions are of higher value as normal transactions.</i>

# %%
time_anaysis[time_anaysis['class'] == 0].amount_value.plot.hist(title='Histogram of non-fraudulent transactions')

# %%
np.mean(time_anaysis.amount_value)
# Out:
# 304978.2154412077

# %%
type(list(time_anaysis['class'])[0])
# Out:
# int

# %%
# As the value of most transaction seems to be only about 150k - 200k. 
# Lets limit the data further

time_anaysis[(time_anaysis['class'] == 0) & 
             (time_anaysis.amount_value <= 200000)].amount_value.plot.hist(title = 'Histogram of non-fraudulent transactions (amount_value <= 30k)')

# %%
time_anaysis[time_anaysis['class'] == 1].amount_value.plot.hist(title = 'Histogram of fraudulent transactions')

# %%
len(time_anaysis[time_anaysis['class'] == 1])
# Out:
# 300000

# %% [markdown]
# There doesn't appears to be any difference visually.
# For the hypothesis test I will be performing a Z-test, with the valid transactions acting as the population.

# %%
population = time_anaysis[time_anaysis['class'] == 0].amount_value
sample = time_anaysis[time_anaysis['class'] == 1].amount_value
sample_mean = sample.mean()
population_std = population.std()
population_mean = population.mean()

# %%
z_score = (sample_mean - population_mean) / (population_std / sample.size ** 0.5)
z_score
# Out:
# -1040.1411293707447

# %% [markdown]
# As the z-score is more than 2.326 we reject the Null hypothesis.
#
# So there is a 99% chance that the amount spend on fraudulent transactions are on average similar or lower value as normal transactions.
# As it can be observed in the histograms in absolute terms normal transactions almost the same value with fraudulent transactions.

# %% [markdown]
# ###  EDA - Second chance (let's see better)
# - plot the amount of transactions vs. time for fraudulent and non-fraudulent as welll as the distributions of amounts for each case.
#
# Does the fraudulent transactions have higher or lower amounts (on average) than non-fraudulent and if they follow any temoporal pattern?

# %%
df = train_df

# %%
import matplotlib.pyplot as plt
fig, ax = plt.subplots(1, 3)
ax[0].scatter(df['time_dif'][df['class'] == 0], 
              df['amount_value'][df['class']==0], 
              color='b' )
ax[0].scatter(df['time_dif'][df['class'] == 1], 
              df['amount_value'][df['class']==1], 
              color='r' , marker='.')
ax[0].legend(['non fraudulent', 'fraudulent'], loc='best')
ax[1].hist(df['amount_value'][df['class']==0], 100, facecolor='b', alpha=0.5,
           label="Distribution of amounts for non-fraudulent", range = [0,2000])
ax[2].hist( df['amount_value'][df['class']==1], 100, facecolor='r', ec="black", lw=0.5, alpha=0.5, 
           label="Distribution of amounts for fraudulent", range = [0,2000])
ax[0].set_xlabel("time_dif")
ax[0].set_ylabel("amount_value")
ax[1].set_xlabel("amount_value")
ax[1].set_ylabel("frequency")
ax[2].set_xlabel("amount_value")
ax[2].set_ylabel("frequency")
ax[1].set_title('non-fraudulent')
ax[2].set_title('fraudulent')
fig.subplots_adjust(left=0, right=2, bottom=0, top=1, hspace=0.05, wspace=0.5)
